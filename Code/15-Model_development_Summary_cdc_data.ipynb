# %%
import import_ipynb
# %run 05-Model_development_LR_cdc_data.ipynb
# %run 08-Model_development_RF_cdc_data.ipynb
# %run 10-Model_development_XGB_cdc_data.ipynb

# %% [markdown]
# <a id="15"></a>
# # <div style="padding:20px;color:white;margin:0;color:darkgreen;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#f2ffe6;overflow:hidden">15. | Model Development: CDC Data: Model Development Summary</div>

# %% [markdown]
# <a id=""></a>
# # <div style="padding:20px;color:white;margin:0;color:darkcyan;font-size:20px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#E0FFFF;overflow:hidden">15.1 | Model Development: CDC Data: First Iteration Comparison</div>

# %%
### LR Iteration 1
mean_train_accuracy_lr_iter1 = 0.8631218464206875
mean_test_accuracy_lr_iter1 = 0.8630597603279723
mean_train_f1_lr_iter1 = 0.2349671684437092
mean_test_f1_lr_iter1 = 0.23435115779847188
mean_train_precision_lr_iter1 = 0.5310645843068807
mean_test_precision_lr_iter1 = 0.5307166533282557
mean_train_recall_lr_iter1 = 0.15090817048064803
mean_test_recall_lr_iter1 = 0.15048381252247248
mean_train_rocauc_score_lr_iter1 = 0.5646649962072564
mean_test_rocauc_score_lr_iter1 = 0.5644511010565825
mean_train_log_loss_value_lr_iter1 = 4.933588724155086
mean_test_log_loss_value_lr_iter1 = 4.935826533761199

# %%
# DT Iteration 1

mean_train_accuracy_dt_iter1 =  0.9745427309996847
mean_test_accuracy_dt_iter1 = 0.810540838852097
mean_train_f1_dt_iter1 = 0.9004759182046909
mean_test_f1_dt_iter1 = 0.3025516249368197
mean_train_precision_dt_iter1 = 0.9889093811515759
mean_test_precision_dt_iter1 = 0.31055395940062486
mean_train_recall_dt_iter1 = 0.8265645324839053
mean_test_recall_dt_iter1 = 0.29496966955147913
mean_train_rocauc_score_dt_iter1 = 0.9125316960074711
mean_test_rocauc_score_dt_iter1 = 0.5944880524620937
mean_train_log_loss_value_dt_iter1 = 0.9175729800808838
mean_test_log_loss_value_dt_iter1 = 6.828800335807903

# %%
# GBM Iteration 1
mean_train_accuracy_gbm_iter1 = 0.8661906732891831
mean_test_accuracy_gbm_iter1 = 0.86559444970041
mean_train_f1_gbm_iter1 = 0.24147761649918179
mean_test_f1_gbm_iter1 = 0.2380423334404534
mean_train_precision_gbm_iter1 = 0.5745233880927765
mean_test_precision_gbm_iter1 = 0.566769049809384
mean_train_recall_gbm_iter1 = 0.15288150595022176
mean_test_recall_gbm_iter1 = 0.15071029294389132
mean_train_rocauc_score_gbm_iter1 = 0.5672747503891726
mean_test_rocauc_score_gbm_iter1 = 0.5660185367688662
mean_train_log_loss_value_gbm_iter1 = 4.822976992195815
mean_test_log_loss_value_gbm_iter1 = 4.844467068571975

# %%
# RF Iteration 1
mean_train_accuracy_iter1_rf =  0.9790099731945758
mean_test_accuracy_iter1_rf =  0.8527869757174393
mean_train_f1_iter1_rf =  0.9202650338009339
mean_test_f1_iter1_rf =  0.27351471417685425
mean_train_precision_iter1_rf =  0.9775172927885404
mean_test_precision_iter1_rf =  0.4377802824015992
mean_train_recall_iter1_rf =  0.8693487223652729
mean_test_recall_iter1_rf =  0.19891923278781815
mean_train_rocauc_score_iter1_rf =  0.933055854695884
mean_test_rocauc_score_iter1_rf =  0.5787802907466263
mean_train_log_loss_value_iter1_rf =  0.7565572508029865
mean_test_log_loss_value_iter1_rf =  5.306095221604305

# %%
#KNN Iteration 1
mean_train_accuracy_knn_iter1 =  0.8847987622201199
mean_test_accuracy_knn_iter1 =  0.8465310627562281
mean_train_f1_knn_iter1 =  0.4509808457318081
mean_test_f1_knn_iter1 =  0.2673047759915856
mean_train_precision_knn_iter1 =  0.6711468250479671
mean_test_precision_knn_iter1 =  0.3992456456759458
mean_train_recall_knn_iter1 =  0.3395858090790113
mean_test_recall_knn_iter1 =  0.20092783940399173
mean_train_rocauc_score_knn_iter1 =  0.656324434443596
mean_test_rocauc_score_knn_iter1 =  0.575987660845352
mean_train_log_loss_value_knn_iter1 =  4.152273484535268
mean_test_log_loss_value_knn_iter1 =  5.5315811800106784

# %%
# XGB Iteration 1
mean_train_accuracy_xgb_cdc_iter1 = 0.8734596736045411
mean_test_accuracy_xgb_cdc_iter1 = 0.8645616524755597
mean_train_f1_xgb_cdc_iter1 = 0.28962881187752504
mean_test_f1_xgb_cdc_iter1 = 0.23793248430914993
mean_train_precision_xgb_cdc_iter1 = 0.6648241132969382
mean_test_precision_xgb_cdc_iter1 = 0.5508872772548475
mean_train_recall_xgb_cdc_iter1 = 0.1851623879466215
mean_test_recall_xgb_cdc_iter1  = 0.1517570130595906
mean_train_rocauc_score_xgb_cdc_iter1 = 0.5850251102615862
mean_test_rocauc_score_xgb_cdc_iter1 = 0.5658571648238453
mean_train_log_loss_value_xgb_cdc_iter1 = 4.560975664343671
mean_test_log_loss_value_xgb_cdc_iter1 = 4.881692853765718

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the metrics and their values for each model
metrics = ['Accuracy', 'F1 Score', 'Precision', 'Recall', 'ROC AUC Score', 'Log Loss']
lr_values_iter1 = [0.8630597603279723, 0.23435115779847188, 0.5307166533282557, 0.15048381252247248, 0.5644511010565825, 4.935826533761199]
dt_values_iter1 = [0.810540838852097, 0.3025516249368197, 0.31055395940062486, 0.29496966955147913, 0.5944880524620937, 6.828800335807903]
rf_values_iter1 = [0.8527869757174393,0.27351471417685425, 0.4377802824015992, 0.19891923278781815, 0.5787802907466263, 5.306095221604305]
knn_values_iter1 = [0.8465310627562281, 0.2673047759915856, 0.3992456456759458, 0.20092783940399173, 0.575987660845352, 5.5315811800106784]
xgb_values_iter1 = [0.8645616524755597, 0.23793248430914993, 0.5508872772548475, 0.1517570130595906, 0.5658571648238453, 4.881692853765718]

# GBM values
gbm_values_iter1 = [0.86559444970041, 0.2380423334404534, 0.566769049809384, 0.15071029294389132, 0.5660185367688662, 4.822976992195815]

# Scale the log loss values
scale_factor = 0.1
lr_values_iter1[-1] *= scale_factor
dt_values_iter1[-1] *= scale_factor
rf_values_iter1[-1] *= scale_factor
knn_values_iter1[-1] *= scale_factor
xgb_values_iter1[-1] *= scale_factor
gbm_values_iter1[-1] *= scale_factor

# Create a bar plot for each metric
x = np.arange(len(metrics))
width = 0.14

fig, ax = plt.subplots(figsize=(16, 8))
bars1 = ax.bar(x - 2.5*width, lr_values_iter1, width, label='LR')
bars2 = ax.bar(x - 1.5*width, dt_values_iter1, width, label='DT')
bars3 = ax.bar(x - 0.5*width, rf_values_iter1, width, label='RF')
bars4 = ax.bar(x + 0.5*width, knn_values_iter1, width, label='KNN')
bars5 = ax.bar(x + 1.5*width, xgb_values_iter1, width, label='XGB')
bars6 = ax.bar(x + 2.5*width, gbm_values_iter1, width, label='GBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Metrics for Iteration 1')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Display the values of each entry in the graph
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)
add_value_labels(bars3)
add_value_labels(bars4)
add_value_labels(bars5)
add_value_labels(bars6)

# Display the plot
plt.show()

# %% [markdown]
# <div style="background-color:white;font-size:15px;font-family:Georgia;border-style: solid;border-color: #254E58;border-width:3px;padding:10px;margin: 1px;color:#254E58;overflow:hidden">
#
# <b>Justification for Selecting LR, RF, and XGB for Further Iterations:</b>
#
# <b>Logistic Regression (LR):</b>
# - **Overall Performance**: LR achieves an accuracy of 0.8631 and a reasonable F1 score of 0.2344. Its precision and recall balance is crucial in identifying positive cases, making it suitable for early detection.
# - **Probability Calibration**: With a log loss of 4.9358, LR demonstrates well-calibrated probabilities, essential for reliable risk assessments.
# - **Significance for Healthcare**: High recall and ROC AUC metrics indicate LR's ability to effectively discriminate between classes, minimizing false negatives—a key requirement in healthcare for timely intervention.
#
# <b>Random Forest (RF):</b>
# - **Overall Performance**: RF delivers a competitive F1 score of 0.2735, showcasing a robust balance between precision and recall.
# - **Versatility and Robustness**: RF's ensemble nature allows it to handle diverse datasets effectively, making it adaptable to different feature distributions.
# - **Significance for Prediction Tasks**: Its ability to model complex interactions within the data is critical for capturing intricate patterns associated with diabetes risk factors.
#
# <b>XGBoost (XGB):</b>
# - **Overall Performance**: XGB achieves the highest accuracy of 0.8646 among the models, indicating strong generalization capabilities.
# - **Efficiency and Scalability**: As a gradient boosting algorithm, XGB is optimized for speed and performance, handling large datasets efficiently.
# - **Significance for Real-Time Applications**: With a log loss of 4.8817, XGB provides well-calibrated probabilities, essential for real-time decision-making in clinical settings.
#
# <b>Exclusion of Decision Tree (DT) , GBM and K-Nearest Neighbors (KNN):</b>
# - **Decision Tree**: While DT offers simplicity and interpretability, its performance metrics, including a lower accuracy of 0.8105 and higher log loss of 6.8288, make it less competitive compared to RF and XGB.
# - **K-Nearest Neighbors**: KNN's accuracy of 0.8465 is overshadowed by its limitations in handling high-dimensional data efficiently and its relatively higher log loss of 5.5316, leading to less reliable probability estimates.
# - GBM and XGB gives almost comparable results, with XGB with slightly better log loss values, and faster trainint times
#
# <b>Conclusion:</b>
# The selection of LR, RF, and XGB is driven by their superior performance metrics, robustness, and suitability for complex prediction tasks, especially in healthcare. Their ability to balance precision, recall, and probability calibration makes them ideal candidates for further optimization in diabetes prediction models.
#
# </div>

# %% [markdown]
# <a id=""></a>
# # <div style="padding:20px;color:white;margin:0;color:darkcyan;font-size:20px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#E0FFFF;overflow:hidden">15.2 | Model Development: CDC Data: Final Iteration Comparison</div>

# %%
##Store CDC Data LR Metrics  
mean_train_accuracy_lr_iter5 = 0.7507986603166582
std_train_accuracy_lr_iter5 = 0.0008884445136276652
mean_test_accuracy_lr_iter5 = 0.7296042257962788
std_test_accuracy_lr_iter5 = 0.0014816999356071768
mean_train_f1_lr_iter5 = 0.7570853607018232
std_train_f1_lr_iter5 = 0.0009554126283889878
mean_test_f1_lr_iter5 = 0.43875905570165863
std_test_f1_lr_iter5 = 0.0032175045259743903
mean_train_precision_lr_iter5 = 0.7384549243259078
std_train_precision_lr_iter5 = 0.0006847161984504377
mean_test_precision_lr_iter5 = 0.30863933149521944
std_test_precision_lr_iter5 = 0.0020496170531913
mean_train_recall_lr_iter5 = 0.7766804510106915
std_train_recall_lr_iter5 = 0.0012790361116307473
mean_test_recall_lr_iter5 = 0.7585868213966073
std_test_recall_lr_iter5 = 0.007944207962722041
mean_train_rocauc_score_lr_iter5 = 0.8246195067505434
std_train_rocauc_score_lr_iter5 = 0.0007275304859253052
mean_test_rocauc_score_lr_iter5 = 0.8173224196073041
std_test_rocauc_score_lr_iter5 = 0.003053226481320132
mean_train_log_loss_value_lr_iter5 = 0.5119922678116801
std_train_log_loss_value_lr_iter5 = 0.000929595265948669
mean_test_log_loss_value_lr_iter5 = 0.5289796644002244
std_test_log_loss_value_lr_iter5 = 0.001659185926978421

# %%
#store CDC Data RF Metrics
mean_train_accuracy_rf_iter3 = 0.8546189539432515
std_train_accuracy_rf_iter3 = 0.0009207565783173383
mean_test_accuracy_rf_iter3 = 0.8076434878587196
std_test_accuracy_rf_iter3 = 0.0014766153162475307
mean_train_f1_rf_iter3 = 0.8552696596211904
std_train_f1_rf_iter3 = 0.0007843208497946547
mean_test_f1_rf_iter3 = 0.44441082255252395
std_test_f1_rf_iter3 = 0.0031693367261735154
mean_train_precision_rf_iter3 = 0.8514658043006527
std_train_precision_rf_iter3 = 0.0016850993913277398
mean_test_precision_rf_iter3 = 0.3718710644831214
std_test_precision_rf_iter3 = 0.002558898631654219
mean_train_recall_rf_iter3 = 0.8591103528984286
std_train_recall_rf_iter3 = 0.0008035017571671017
mean_test_recall_rf_iter3 = 0.5521703163182555
std_test_recall_rf_iter3 = 0.007102672543886504
mean_train_rocauc_score_rf_iter3 = 0.9414235141284297
std_train_rocauc_score_rf_iter3 = 0.0005666352435126756
mean_test_rocauc_score_rf_iter3 = 0.8135295570225105
std_test_rocauc_score_rf_iter3 = 0.0030669986701743882
mean_train_log_loss_value_rf_iter3 = 0.3329925959369266
std_train_log_loss_value_rf_iter3 = 0.0013685937617924492
mean_test_log_loss_value_rf_iter3 = 0.39555978977244866
std_test_log_loss_value_rf_iter3 = 0.0008279094329791564

# %%
# Store CDC Data XGB Metrics 
# mean_train_accuracy_xgb_cdc_iter3 = 0.9020983899048354
# std_train_accuracy_xgb_cdc_iter3 = 0.0004094975473273961
# mean_test_accuracy_xgb_cdc_iter3 = 0.8559247871333964
# std_test_accuracy_xgb_cdc_iter3 = 0.00046731933022773947
# mean_train_f1_xgb_cdc_iter3 = 0.8970914622711932
# std_train_f1_xgb_cdc_iter3 = 0.0004902696843248843
# mean_test_f1_xgb_cdc_iter3 = 0.3483000620579159
# std_test_f1_xgb_cdc_iter3 = 0.003731722582134302
# mean_train_precision_xgb_cdc_iter3 = 0.9454418257667987
# std_train_precision_xgb_cdc_iter3 = 0.0005751438936003786
# mean_test_precision_xgb_cdc_iter3 = 0.4710350949953039
# std_test_precision_xgb_cdc_iter3 = 0.002373740479783352
# mean_train_recall_xgb_cdc_iter3 = 0.8534470117126608
# std_train_recall_xgb_cdc_iter3 = 0.0010890174229609701
# mean_test_recall_xgb_cdc_iter3 = 0.2763540073668665
# std_test_recall_xgb_cdc_iter3 = 0.005107657293072774
# mean_train_rocauc_score_xgb_cdc_iter3 = 0.964130661575366
# std_train_rocauc_score_xgb_cdc_iter3 = 0.0002816775000009513
# mean_test_rocauc_score_xgb_cdc_iter3 = 0.8134147866536752
# std_test_rocauc_score_xgb_cdc_iter3 = 0.0027555875457840576
# mean_train_log_loss_value_xgb_cdc_iter3 = 0.22755956496352409
# std_train_log_loss_value_xgb_cdc_iter3 = 0.000889394469259587
# mean_test_log_loss_value_xgb_cdc_iter3 = 0.3315943408397568
# std_test_log_loss_value_xgb_cdc_iter3 = 0.0012821630643084726

mean_train_accuracy_xgb_cdc_iter3= 0.8736122175197238
std_train_accuracy_xgb_cdc_iter3= 0.0005042378913261396
mean_test_accuracy_xgb_cdc_iter3= 0.7903736991485336
std_test_accuracy_xgb_cdc_iter3= 0.0017764531722670172
mean_train_f1_xgb_cdc_iter3= 0.8799672412166657
std_train_f1_xgb_cdc_iter3= 0.0004415385162502748
mean_test_f1_xgb_cdc_iter3= 0.4484307518402093
std_test_f1_xgb_cdc_iter3= 0.005388823580765282
mean_train_precision_xgb_cdc_iter3= 0.837840367751501
std_train_precision_xgb_cdc_iter3= 0.0007193239618015124
mean_test_precision_xgb_cdc_iter3= 0.3539942790117854
std_test_precision_xgb_cdc_iter3= 0.003645223069681947
mean_train_recall_xgb_cdc_iter3= 0.9265551853144786
std_train_recall_xgb_cdc_iter3 = 0.00045397778203849353
mean_test_recall_xgb_cdc_iter3= 0.6116395009547233
std_test_recall_xgb_cdc_iter3= 0.010592507925624621
mean_train_rocauc_score_xgb_cdc_iter3= 0.964130661575366
std_train_rocauc_score_xgb_cdc_iter3= 0.0002816775000009513
mean_test_rocauc_score_xgb_cdc_iter3= 0.8134147866536752
std_test_rocauc_score_xgb_cdc_iter3= 0.0027555875457840576
mean_train_log_loss_value_xgb_cdc_iter3= 0.22755956496352409
std_train_log_loss_value_xgb_cdc_iter3= 0.000889394469259587
mean_test_log_loss_value_xgb_cdc_iter3= 0.3315943408397568
std_test_log_loss_value_xgb_cdc_iter3= 0.0012821630643084726

# %%
# Plot all metrics across LR, RF, and XGB models and display the values of each entry in the graph
fig, ax = plt.subplots(figsize=(12, 6))
bars1 = ax.bar(x - width, lr_values, width, label='LR')
bars2 = ax.bar(x, rf_values, width, label='RF')
xgb_values = [mean_test_accuracy_xgb_cdc_iter3, mean_test_f1_xgb_cdc_iter3, mean_test_precision_xgb_cdc_iter3, mean_test_recall_xgb_cdc_iter3, mean_test_rocauc_score_xgb_cdc_iter3, mean_test_log_loss_value_xgb_cdc_iter3]
bars3 = ax.bar(x + width, xgb_values, width, label='XGB')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Metrics')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Display the values of each entry in the graph
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)
add_value_labels(bars3)

# Display the plot
plt.show()
# Out:
# [0.7903736991485336, 0.4484307518402093, 0.3539942790117854, 0.6116395009547233, 0.8134147866536752, 0.3315943408397568]

# %% [markdown]
# <div style="background-color:white;font-size:15px;font-family:Georgia;border-style: solid;border-color: #254E58;border-width:3px;padding:10px;margin: 1px;color:#254E58;overflow:hidden">
#
# <b>Best Model Objectively:</b>
#
# <b>Accuracy:</b>
# - **XGB**: Test Accuracy - 0.8559
# - **RF**: Test Accuracy - 0.8076
# - **LR**: Test Accuracy - 0.7296
# - **Conclusion**: XGB has the highest test accuracy, indicating better overall performance in correctly predicting both classes.
#
# <b>F1 Score:</b>
# - **XGB**: Test F1 - 0.4583
# - **RF**: Test F1 - 0.4444
# - **LR**: Test F1 - 0.4388
# - **Conclusion**: RF has the highest test F1 score, suggesting a better balance between precision and recall.
#
# <b>Precision:</b>
# - **XGB**: Test Precision - 0.4710
# - **RF**: Test Precision - 0.3719
# - **LR**: Test Precision - 0.3086
# - **Conclusion**: XGB has the highest test precision, indicating fewer false positives.
#
# <b>Recall:</b>
# - **XGB**: Test Recall - 0.2764
# - **RF**: Test Recall - 0.5522
# - **LR**: Test Recall - 0.7586
# - **Conclusion**: LR has the highest test recall, meaning it captures more actual positive cases.
#
# <b>ROC AUC:</b>
# - **XGB**: Test ROC AUC - 0.8134
# - **RF**: Test ROC AUC - 0.8135
# - **LR**: Test ROC AUC - 0.8173
# - **Conclusion**: LR has the highest test ROC AUC, indicating the best class discrimination capability.
#
# <b>Log Loss:</b>
# - **XGB**: Test Log Loss - 0.3316
# - **RF**: Test Log Loss - 0.3956
# - **LR**: Test Log Loss - 0.5290
# - **Conclusion**: XGB has the lowest test log loss, indicating better probability calibration.
#
# <b>Most Suitable for Diabetes Prediction:</b>
#
# While XGBoost appears to be the best model in terms of accuracy and probability calibration, **Logistic Regression** may be more suitable for managing early detection and prevention in patients due to its high recall and ROC AUC. High recall is crucial in healthcare settings to ensure that all potential diabetes cases are flagged for further testing, minimizing the risk of false negatives.
#
# <b>Conclusion:</b>
#
# - **XGBoost** is the best model in terms of accuracy and probability calibration, making it a robust choice for general prediction tasks.
# - **Logistic Regression** is more suited for diabetes prediction where early detection and prevention are critical, as it prioritizes capturing positive cases despite a trade-off in precision. This approach helps ensure that fewer cases of diabetes are missed, which is vital for effective intervention and management.
#
# </div>

# %% [markdown]
# <a id=""></a>
# # <div style="padding:20px;color:white;margin:0;color:darkcyan;font-size:20px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#E0FFFF;overflow:hidden">15.3 | Model Development: CDC Data vs PIMA Data: RF Comparison</div>

# %%
mean_train_accuracy_pima_rf_iter3 = 0.9791657511169707
mean_test_accuracy_pima_rf_iter3 = 0.7720258575748098
mean_train_f1_pima_rf_iter3 = 0.9791679277862151
mean_test_f1_pima_rf_iter3 = 0.6751672766867844
mean_train_precision_pima_rf_iter3 = 0.9789335027653134
mean_test_precision_pima_rf_iter3 = 0.6454515080623455
mean_train_recall_pima_rf_iter3 = 0.9794345565077271
mean_test_recall_pima_rf_iter3 = 0.7184088806660499
mean_train_rocauc_score_pima_rf_iter3 = 0.9987132106301198
mean_test_rocauc_score_pima_rf_iter3 = 0.8301301995148467
mean_train_log_loss_value_pima_rf_iter3 = 0.19384749580005686
mean_test_log_loss_value_pima_rf_iter3 = 0.4877220629736173

# %%
# Define the metrics and their values for each model
metrics = ['Accuracy', 'F1 Score', 'Precision', 'Recall', 'ROC AUC Score', 'Log Loss']
cdc_rf_values_iter3 = [mean_test_accuracy_rf_iter3, mean_test_f1_rf_iter3, mean_test_precision_rf_iter3, mean_test_recall_rf_iter3, mean_test_rocauc_score_rf_iter3, mean_test_log_loss_value_rf_iter3]
pima_rf_values_iter3 = [mean_test_accuracy_pima_rf_iter3, mean_test_f1_pima_rf_iter3, mean_test_precision_pima_rf_iter3, mean_test_recall_pima_rf_iter3, mean_test_rocauc_score_pima_rf_iter3, mean_test_log_loss_value_pima_rf_iter3]

# Create a bar plot for each metric
x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 7))
bars1 = ax.bar(x - width/2, cdc_rf_values_iter3, width, label='CDC RF Iter3')
bars2 = ax.bar(x + width/2, pima_rf_values_iter3, width, label='PIMA RF Iter3')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of CDC Iter3 and PIMA Iter3 Metrics for RF Model')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Display the values of each entry in the graph
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

# Display the plot
plt.show()
